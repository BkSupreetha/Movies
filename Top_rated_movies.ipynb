# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv('movies.csv')
data
# Out:
#       Unnamed: 0      id  adult                     title
# 0              0     278  False  The Shawshank Redemption
# 1              1     238  False             The Godfather
# 2              2     240  False     The Godfather Part II
# 3              3     424  False          Schindler's List
# 4              4     389  False              12 Angry Men
# ...          ...     ...    ...                       ...
# 5615        5615   72387  False                      Safe
# 5616        5616   13680  False             The Game Plan
# 5617        5617   12242  False                  Mulan II
# 5618        5618   11395  False          The Santa Clause
# 5619        5619  203793  False                Stalingrad
#
# [5620 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['id', 'adult', 'title'], dtype='object')

# %%
#setting first column as index
data = data.set_index('Unnamed: 0')

# %%
data
# Out:
#            id  adult                     title
# Index
# 0         278  False  The Shawshank Redemption
# 1         238  False             The Godfather
# 2         240  False     The Godfather Part II
# 3         424  False          Schindler's List
# 4         389  False              12 Angry Men
# ...       ...    ...                       ...
# 5615    72387  False                      Safe
# 5616    13680  False             The Game Plan
# 5617    12242  False                  Mulan II
# 5618    11395  False          The Santa Clause
# 5619   203793  False                Stalingrad
#
# [5620 rows x 3 columns]

# %%
#renaming the index column
data = data.rename_axis('Index')

# %%
#checking for null values
data.isnull().sum()
# Out:
# id       0
# adult    0
# title    0
# dtype: int64

# %%
#selecting non adult movies
print((data['adult']=='False'), data[['title', 'id']])
(data['adult']=='False').count()
# Out:
# Index
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 5615    True
# 5616    True
# 5617    True
# 5618    True
# 5619    True
# Name: adult, Length: 5620, dtype: bool                           title      id
# Index
# 0      The Shawshank Redemption     278
# 1                 The Godfather     238
# 2         The Godfather Part II     240
# 3              Schindler's List     424
# 4                  12 Angry Men     389
# ...                         ...     ...
# 5615                       Safe   72387
# 5616              The Game Plan   13680
# 5617                   Mulan II   12242
# 5618           The Santa Clause   11395
# 5619                 Stalingrad  203793
#
# [5620 rows x 2 columns]
# 5620

# %%
#selecting non adult movies using lambda function
Non_Adult_movie =  data[['title', 'id']].apply(lambda x: x[data['adult']=='False'])
Non_Adult_movie
# Out:
#                           title      id
# Index
# 0      The Shawshank Redemption     278
# 1                 The Godfather     238
# 2         The Godfather Part II     240
# 3              Schindler's List     424
# 4                  12 Angry Men     389
# ...                         ...     ...
# 5615                       Safe   72387
# 5616              The Game Plan   13680
# 5617                   Mulan II   12242
# 5618           The Santa Clause   11395
# 5619                 Stalingrad  203793
#
# [5620 rows x 2 columns]

# %%
Adult_movie =  data[['title', 'id']].apply(lambda x: x[data['adult']!='False'])
Adult_movie
# Out:
# Empty DataFrame
# Columns: [title, id]
# Index: []

# %%
print('Total no. of titles ',data['title'].count())
unique_titles = data['title'].unique()
print('Total no. of unique titles: ',unique_titles.size)
# Out:
# Total no. of titles  5620
# Total no. of unique titles:  5511

# %% [markdown]
# # Since we can see that there is difference between no. of titless and no. of unique titles it is obvious that few movie titles have been repeated,  lets explore those itles and their count

# %%
#checking for title values and their count of appearance
title_recurring_counts = data['title'].value_counts()
title_recurring_counts
# Out:
# title
# The Killer               3
# Beauty and the Beast     3
# Les Misérables           3
# The Innocents            3
# The Mummy                2
#                         ..
# Belladonna of Sadness    1
# The Lunchbox             1
# Meet Joe Black           1
# The Bandit               1
# The Santa Clause         1
# Name: count, Length: 5511, dtype: int64

# %%
#printing repeated title names
repeated_titles = title_recurring_counts[title_recurring_counts > 1]
repeated_titles
# Out:
# title
# The Killer                   3
# Beauty and the Beast         3
# Les Misérables               3
# The Innocents                3
# The Mummy                    2
#                             ..
# 12 Angry Men                 2
# Miracle in Cell No. 7        2
# The Party                    2
# Adventures in Babysitting    2
# Hairspray                    2
# Name: count, Length: 105, dtype: int64

# %%
#Deleting repeated titles
data.drop_duplicates(subset='title', keep='first', inplace=True)
data
# Out:
#           id  adult                        title
# Index
# 0        278  False     The Shawshank Redemption
# 1        238  False                The Godfather
# 2        240  False        The Godfather Part II
# 3        424  False             Schindler's List
# 4        389  False                 12 Angry Men
# ...      ...    ...                          ...
# 5614   13573  False  The United States of Leland
# 5615   72387  False                         Safe
# 5616   13680  False                The Game Plan
# 5617   12242  False                     Mulan II
# 5618   11395  False             The Santa Clause
#
# [5511 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# id       0
# adult    0
# title    0
# dtype: int64
